# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryabhatt-O/Computational-Geometry/blob/main/My_rough.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi, voronoi_plot_2d
import numpy as np
M = 30
points = np.random.uniform(0, 300, size=(M, 2))
# points = np.array([[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2],
#                    [2, 0], [2, 1], [2, 2],[9,9],[4,4],[7,10],[-9,8],[-6,12]])
vor = Voronoi(points,qhull_options='Qbb Qc Qx')
voronoi_plot_2d(vor,show_vertices = True)

new_point = [20,30]
new_point1 = [30,20]
new_point2 = [40,10]
new_point3 = [50,77]
new_point4 = [60,12]
new_point5 = [70,99]
new_point6 = [80,65]
new_point7 = [90,112]
new_point8 = [100,212]
new_point9 = [110,162]
new_point10 = [120,138]
new_point11 = [130,76]
new_point12 = [140,80]
new_point13 = [150,50]
new_point14 = [160,70]
new_point15 = [170,100]
new_point16 = [180,90]
new_point17 = [190,20]
new_point18 = [200,60]
new_point19 = [210,220]

plt.plot(new_point[0], new_point[1], 'ko')
plt.plot(new_point1[0], new_point1[1], 'ko')
plt.plot(new_point2[0], new_point2[1], 'ko')
plt.plot(new_point3[0], new_point3[1], 'ko')
plt.plot(new_point4[0], new_point4[1], 'ko')
plt.plot(new_point5[0], new_point5[1], 'ko')
plt.plot(new_point6[0], new_point6[1], 'ko')
plt.plot(new_point7[0], new_point7[1], 'ko')
plt.plot(new_point8[0], new_point8[1], 'ko')
plt.plot(new_point9[0], new_point9[1], 'ko')
plt.plot(new_point10[0], new_point10[1], 'ko')
plt.plot(new_point11[0], new_point11[1], 'ko')
plt.plot(new_point12[0], new_point12[1], 'ko')
plt.plot(new_point13[0], new_point13[1], 'ko')
plt.plot(new_point14[0], new_point14[1], 'ko')
plt.plot(new_point15[0], new_point15[1], 'ko')
plt.plot(new_point16[0], new_point16[1], 'ko')
plt.plot(new_point17[0], new_point17[1], 'ko')
plt.plot(new_point18[0], new_point18[1], 'ko')
plt.plot(new_point19[0], new_point19[1], 'ko')


# print(vor.vertices)
# colorize
for region in vor.regions:
    if not -1 in region:
        polygon = [vor.vertices[i] for i in region]
        plt.fill(*zip(*polygon))
print(points)
for i, reg in enumerate(vor.regions):
  print('Region:', i)
  print('Indices of vertices of Voronoi region:', reg)
  b = np.where(vor.point_region == i)[0][0]
  print('Associated point index refer to input points:',b)

# %%
import random
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi, voronoi_plot_2d
import numpy as np
M = 30
# points = np.random.uniform(0, 300, size=(M, 2))
points = np.array([[0, 0], [3,4], [1, -2], [8,-4], [5, 1], [-6,7],
                   [-3,-7], [2, 1], [2, 2],[9,9],[2,3],[7,10],[-9,8],[-6,12],[10,10],[8,12],[9,13],[3,9],[15,10]])
vor = Voronoi(points,qhull_options='Qbb Qc Qx')
voronoi_plot_2d(vor,show_vertices = True)

new_point = [2,3]
new_point1 = [3,2]
new_point2 = [4,1]
new_point3 = [5,7]
new_point4 = [6,1]
new_point5 = [7,9]
new_point6 = [8,6]
new_point7 = [12,9]
# new_point8 = [100,212]
# new_point9 = [110,162]
# new_point10 = [120,138]
# new_point11 = [130,76]
# new_point12 = [140,80]
# new_point13 = [150,50]
# new_point14 = [160,70]
# new_point15 = [170,100]
# new_point16 = [180,90]
# new_point17 = [190,20]
# new_point18 = [200,60]
# new_point19 = [210,220]

plt.plot(new_point[0], new_point[1], 'ko')
plt.plot(new_point1[0], new_point1[1], 'ko')
plt.plot(new_point2[0], new_point2[1], 'ko')
plt.plot(new_point3[0], new_point3[1], 'ko')
plt.plot(new_point4[0], new_point4[1], 'ko')
plt.plot(new_point5[0], new_point5[1], 'ko')
plt.plot(new_point6[0], new_point6[1], 'ko')
plt.plot(new_point7[0], new_point7[1], 'ko')
# plt.plot(new_point8[0], new_point8[1], 'ko')
# plt.plot(new_point9[0], new_point9[1], 'ko')
# plt.plot(new_point10[0], new_point10[1], 'ko')
# plt.plot(new_point11[0], new_point11[1], 'ko')
# plt.plot(new_point12[0], new_point12[1], 'ko')
# plt.plot(new_point13[0], new_point13[1], 'ko')
# plt.plot(new_point14[0], new_point14[1], 'ko')
# plt.plot(new_point15[0], new_point15[1], 'ko')
# plt.plot(new_point16[0], new_point16[1], 'ko')
# plt.plot(new_point17[0], new_point17[1], 'ko')
# plt.plot(new_point18[0], new_point18[1], 'ko')
# plt.plot(new_point19[0], new_point19[1], 'ko')


# print(vor.vertices)
# colorize
for region in vor.regions:
    if not -1 in region:
        polygon = [vor.vertices[i] for i in region]
        plt.fill(*zip(*polygon))
print(points)
for i, reg in enumerate(vor.regions):
  print('Region:', i)
  print('Indices of vertices of Voronoi region:', reg)
  b = np.where(vor.point_region == i)[0][0]
  print('Associated point index refer to input points:',b)

# %%
point_index = np.sum((points - new_point)**2, axis=1)
point_index1 = np.sum((points - new_point1)**2, axis=1)
point_index2 = np.sum((points - new_point2)**2, axis=1)
point_index3 = np.sum((points - new_point3)**2, axis=1)
point_index4 = np.sum((points - new_point4)**2, axis=1)
point_index5 = np.sum((points - new_point5)**2, axis=1)
point_index6 = np.sum((points - new_point6)**2, axis=1)
point_index7 = np.sum((points - new_point7)**2, axis=1)
print(*point_index)
print(*point_index1)
print(*point_index2)
print(*point_index3)
print(*point_index4)
print(*point_index5)
print(*point_index6)
print(*point_index7)

# %%
friends_location = np.array([[2, 3],[3, 2],[4,1],[5,7],[6,1],[7,9],[8,6],[12,9]])
Restro_1 = [0,0]
Restro_2 = [3,4]
Restro_3 = [1,-2]
Restro_4 = [-8,-4]
Restro_5  = [5,1]
Restro_6  = [-6,7]
Restro_7  = [-3,-7]
Restro_8  = [2,1]
Restro_9  = [2,2]
Restro_10  = [9,9]
Restro_11  = [2,3]
Restro_12 = [7,10]
Restro_13  = [-9,8]
Restro_14  = [-6,12]
Restro_15  = [10,10]
Restro_16 = [8,12]
Restro_17 = [9,13]
Restro_18 = [3,9]
Restro_19 = [15,10]

#1
distance1 = np.sum((friends_location - Restro_1)**2, axis=1)
total1 = sum(distance1)
print("distance from each friends' house to 1st restro: ", distance1," total distance: " ,total1)


 
#2
distance2 = np.sum((friends_location - Restro_2)**2, axis=1)
total2 = sum(distance2)
print("distance from each friends' house to 2nd restro: ", distance2," total distance: " ,total2)

#3
distance3 = np.sum((friends_location - Restro_3)**2, axis=1)
total3 = sum(distance3)
print("distance from each friends' house to 3rd restro: ", distance3," total distance: " ,total3)

#4
distance4 = np.sum((friends_location - Restro_4)**2, axis=1)
total4 = sum(distance4)
print("distance from each friends' house to 4th restro: ", distance4," total distance: " ,total4)

#5
distance5 = np.sum((friends_location - Restro_5)**2, axis=1)
total5 = sum(distance5)
print("distance from each friends' house to 5th restro: ", distance5," total distance: " ,total5)

#6
distance6 = np.sum((friends_location - Restro_6)**2, axis=1)
total6 = sum(distance6)
print("distance from each friends' house to 6th restro: ", distance6,  " total distance: " ,total6)

#7
distance7 = np.sum((friends_location - Restro_7)**2, axis=1)
total7 = sum(distance7)
print("distance from each friends' house to 7th restro: ", distance7," total distance: " ,total7)

#8
distance8 = np.sum((friends_location - Restro_8)**2, axis=1)
total8 = sum(distance8)
print("distance from each friends' house to 8th restro: ", distance8," total distance: " ,total8)

#9
distance9 = np.sum((friends_location - Restro_9)**2, axis=1)
total9 = sum(distance9)
print("distance from each friends' house to 9th restro: ", distance9, " total distance: " ,total9)

#10
distance10 = np.sum((friends_location - Restro_10)**2, axis=1)
total10 = sum(distance10)
print("distance from each friends' house to 10th restro: ", distance10," total distance: " ,total10)

#11
distance11 = np.sum((friends_location - Restro_11)**2, axis=1)
total11 = sum(distance11)
print("distance from each friends' house to 11th restro: ", distance11," total distance: " ,total11)

#12
distance12 = np.sum((friends_location - Restro_12)**2, axis=1)
total12 = sum(distance12)
print("distance from each friends' house to 12th restro: ", distance12," total distance: " ,total12)

#13
distance13 = np.sum((friends_location - Restro_13)**2, axis=1)
total13 = sum(distance13)
print("distance from each friends' house to 13th restro: ", distance13," total distance: " ,total13)

#14
distance14 = np.sum((friends_location - Restro_14)**2, axis=1)
total14 = sum(distance14)
print("distance from each friends' house to 14th restro: ", distance14," total distance: " ,total14)

#15
distance15 = np.sum((friends_location - Restro_15)**2, axis=1)
total15 = sum(distance15)
print("distance from each friends' house to 15th restro: ", distance15," total distance: " ,total15)

#16
distance16 = np.sum((friends_location - Restro_16)**2, axis=1)
total16 = sum(distance16)
print("distance from each friends' house to 16th restro: ", distance16," total distance: " ,total16)

#17
distance17 = np.sum((friends_location - Restro_17)**2, axis=1)
total17 = sum(distance17)
print("distance from each friends' house to 17th restro: ", distance17," total distance: " ,total17)

#18
distance18 = np.sum((friends_location - Restro_18)**2, axis=1)
total18 = sum(distance18)
print("distance from each friends' house to 18th restro: ", distance18," total distance: " ,total18)

#19
distance19 = np.sum((friends_location - Restro_19)**2, axis=1)
total19 = sum(distance19)
print("distance from each friends' house to 19th restro: ", distance19," total distance: " ,total19)

# %% [markdown]
# # **little proof of 2nd smallest theory** :) :)

# %%
from random import *
import heapq
import numpy as np
restro = np.array([[2, 3],[5, 2],[4,1],[5,7],[6,1],[7,9],[8,6],[12,9],[10,9]])
friends_location = np.array([[0, 0], [3,4], [1, -2], [8,-4], [5, 1], [-6,7],
                   [-3,-7], [2, 1], [2, 2],[9,9],[2,3],[7,10],[-9,8],[-6,12],[11,12],[8,12],[9,13],[3,9],[15,10]])

#random
# M = randint(15, 25)
# restro = np.random.uniform(10,100, size=(M, 2))
# N = randint(50, 100)
# friends_location = np.random.uniform(10, 100, size=(N, 2))


total = []
index = []
length = []
for i in range(len(restro)):
  distance = np.sum((friends_location - restro[i])**2, axis=1)
  a = len(set(distance))
  print(distance,a)
  length.append(a)
  print(sum(distance),i+1)
  total.append(sum(distance))
  index.append(i+1)
 

print(total)
print(index)

second_small = heapq.nsmallest(2,total)
print(second_small)
for i in range(len(total)):
  if total[i] == second_small[1]:
    ("my req index",index[i],a)


# For checking from voronoi

from random import *
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi, voronoi_plot_2d
import numpy as np
vor = Voronoi(restro,qhull_options='Qbb Qc Qx')
voronoi_plot_2d(vor,show_vertices = True)

#for plotting my friends location 
x, y = friends_location.T
plt.plot(x,y, 'ko')



for region in vor.regions:
    if not -1 in region:
        polygon = [vor.vertices[i] for i in region]
        plt.fill(*zip(*polygon))



for i,a in enumerate(restro):
  print(a,i+1)


print(total,length)



#with the help of length[] & total[]
indexF = []
for i in range(len(length)):
  if length[i] == min(length):
    indexF.append(i+1)


indexF
length
final_index = []

for i in indexF:
  print(total[i-1])
  if total[i-1] < total[i]:
    final_index.append(i)

print("My Final Index",final_index)

# %%
edge_points = []
for vpair in vor.ridge_vertices:
  if vpair[0] >= 0 and vpair[1] >= 0:
    v0 = vor.vertices[vpair[0]]
    v1 = vor.vertices[vpair[1]]
    # print(v0,v1)
    edge_points.append(np.array([v0,v1]))

for a , i in enumerate(edge_points):
  print(a+1,i,end = '\n')

# %%
# For checking from voronoi

from random import *
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi, voronoi_plot_2d
import numpy as np

friends_location = np.array([[5,6],[1, 12],[11,1],[7,5],[3,15],[18,10],[8,20],[12,18],[6,21],[13,31],[16,9],[12,2],[20,19]])
restro = np.array([[3,4],[7,9],[11,15],[23,17],[12,16],[22,13]])



vor = Voronoi(restro,qhull_options='Qbb Qc Qx')
voronoi_plot_2d(vor,show_vertices = True)

#for plotting my friends location 
x, y = friends_location.T
plt.plot(x,y, 'ko')



for region in vor.regions:
    if not -1 in region:
        polygon = [vor.vertices[i] for i in region]
        plt.fill(*zip(*polygon))

# %%
from random import *
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi, voronoi_plot_2d
import numpy as np
restro = np.array([[2, 3],[5, 2],[4,11],[9,7],[6,1],[7,5],[8,6],[12,10],[10,9]])
friends_location = np.array([[0, 0], [3,5], [1, 12], [4,14], [5, 4], [15,6],
                   [13,19], [2, 11], [14, 2],[9,9],[6,3],[7,7],[19,8],[16,12],[11,16],[8,19],[12,13],[18,17],[15,10]])

vor = Voronoi(restro,qhull_options='Qbb Qc Qx')
voronoi_plot_2d(vor,show_vertices = True)

#for plotting my friends location 
x, y = friends_location.T
plt.plot(x,y, 'ko')




for region in vor.regions:
    if not -1 in region:
        polygon = [vor.vertices[i] for i in region]
        plt.fill(*zip(*polygon))

# %%
import numpy as np

restro = [[2, 3],[5, 2],[4,11],[9,7],[6,1],[7,5],[8,6],[12,10],[10,9]]
friends_location = np.array([[ 7.45551508,  5.91916609],
       [ 2.29479859,  3.08426414],
       [11.40723254,  9.78434511],
       [ 9.56002355,  8.85562736],
       [ 4.85309039,  1.98652602],
       [ 1.37997151,  3.80454738],
       [ 4.88075961,  1.63630707],
       [ 2.59685708,  3.0835286 ],
       [ 9.78062274,  9.08866152],
       [ 6.49526892,  8.16509474],
       [ 5.09673349,  6.30086143],
       [ 5.18153494,  1.77719189],
       [ 4.51759916,  0.59339006],
       [ 8.23382418,  5.36660431],
       [ 6.11162495,  7.97767112],
       [ 6.50661778,  0.94147021],
       [11.79524549,  8.97360086],
       [ 5.31742305,  7.06927185],
       [ 3.74726787,  1.10630291],
       [ 4.14241705,  0.90041266]])


restro_x = []
for i in restro:
  restro_x.append((i[0]))

friends_location_x = []
for i in friends_location:
  friends_location_x.append((i[0]))

print("restro_x: ",sorted(restro_x))
print("friends_location_x: ",sorted(friends_location_x))

# %%
restro_y = []
for i in restro:
  restro_y.append((i[1]))

friends_location_y = []
for i in friends_location:
  friends_location_y.append((i[1]))

print("restro_y: ",sorted(restro_y))
print("friends_location_y: ",sorted(friends_location_y))

# %%
restro = np.array([[2, 3],[5, 2],[4,11],[9,7],[6,1],[7,5],[8,6],[12,10],[10,9]])
friends_location = np.array([[0, 0], [3,5], [1, -2], [4,-4], [5, 4], [-5,-6],
                   [-3,-7], [2, 11], [13, 2],[9,9],[6,3],[7,-8],[-9,8],[-6,12],[11,16],[8,-9],[12,13],[18,17],[15,10]])

# %% [markdown]
# [Gaussian Distribution](https://radiant-brushlands-42789.herokuapp.com/towardsdatascience.com/all-you-need-to-know-about-normal-distribution-3f67df0691f8)

# %%
import numpy as np
import matplotlib.pyplot as plt
mu = 2.5
sigma = .5
# bins = 30
H= np.random.normal(2.5, .5, (30,2))
# count, bins, ignored = plt.hist(H, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *np.exp( - (bins - mu)**2 / (2 * sigma**2) ),linewidth=2, color='r')
plt.show()
for i,j in enumerate(H):
  print(j,i+1)

# %%
#2,#7,#11,#17 #19 #22 #24 #9 #25 --> restro#
from random import *
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi, voronoi_plot_2d
import numpy as np
restro = np.array([[2.01499758,3.09596982],[2.66908539,1.98204602],[3.02311702,2.08882259],[2.60733283,1.09369312],[3.40384348,1.35911428],[2.17628007,2.97768896],[3.0603175,2.24053827],[2.10766079,2.64644531],[2.330151,2.17140436]])
friends_location = np.array([[3.37939881,2.11961583], [2.6401608,2.40307182], [3.18142498,2.5208163 ], [2.70262255,2.87494491],[1.97179267,3.61788197], [2.34719729,1.92511913],[2.10766079,2.64644531], [2.00350574,2.54170935], [1.97272519,2.79726616],[2.92279028,2.31337817],[2.42390199,2.82046777],[1.81856972,2.9190036 ],[2.24953374,1.79493875],[2.47506761,1.99936298],[3.02869114,2.29463348],[2.08692693,3.14014363],[3.15041189,2.56714967],[3.13796814,1.83667734],[2.21730427,3.11166138],[2.73911786,3.37997088],[2.47522123,2.86980951],[2.43703634,2.45819992]])
vor = Voronoi(restro,qhull_options='Qbb Qc Qx')
voronoi_plot_2d(vor,show_vertices = True)

#for plotting my friends location 
x, y = friends_location.T
plt.plot(x,y, 'ko')

v_x,v_y =(2.04,2.82)
plt.plot(v_x,v_y, 'ro')



for region in vor.regions:
    if not -1 in region:
        polygon = [vor.vertices[i] for i in region]
        plt.fill(*zip(*polygon))

# %%
restro_x = []
friends_location
for i in restro1:
  restro_x.append((i[0]))

friends_location_x = []
for i in friends_location:
  friends_location_x.append((i[0]))

print("restro_x: ",sorted(restro_x))
print("friends_location_x: ",sorted(friends_location_x))


restro_y = []
for i in restro:
  restro_y.append((i[1]))

friends_location_y = []
for i in friends_location:
  friends_location_y.append((i[1]))

print("restro_y: ",sorted(restro_y))
print("friends_location_y: ",sorted(friends_location_y))

# %%
r_x1 = np.array([2.01499758, 2.10766079, 2.17628007, 2.330151, 2.60733283, 2.66908539, 3.02311702, 3.0603175, 3.40384348])
bisector_x = (r_x1[1:] + r_x1[:-1]) / 2
print("bisector_x: ",bisector_x)

# %%
r_y = np.array([1.09369312, 1.35911428, 1.98204602, 2.08882259, 2.17140436, 2.24053827, 2.64644531, 2.97768896, 3.09596982])
bisector_y = (r_y[1:] + r_y[:-1]) / 2
bisector_y

# %%
from random import *
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi, voronoi_plot_2d
import numpy as np
restro = [[2, 3],[5, 2],[4,11],[9,7],[6,1],[7,5],[8,6],[12,10],[10,9]]
friends_location = np.array([[ 7.45551508,  5.91916609],
       [ 2.29479859,  3.08426414],
       [11.40723254,  9.78434511],
       [ 9.56002355,  8.85562736],
       [ 4.85309039,  1.98652602],
       [ 1.37997151,  3.80454738],
       [ 4.88075961,  1.63630707],
       [ 2.59685708,  3.0835286 ],
       [ 9.78062274,  9.08866152],
       [ 6.49526892,  8.16509474],
       [ 5.09673349,  6.30086143],
       [ 5.18153494,  1.77719189],
       [ 4.51759916,  0.59339006],
       [ 8.23382418,  5.36660431],
       [ 6.11162495,  7.97767112],
       [ 6.50661778,  0.94147021],
       [11.79524549,  8.97360086],
       [ 5.31742305,  7.06927185],
       [ 3.74726787,  1.10630291],
       [ 4.14241705,  0.90041266]])
vor = Voronoi(restro,qhull_options='Qbb Qc Qx')
voronoi_plot_2d(vor,show_vertices = True)

#for plotting my friends location 
x, y = friends_location.T
plt.plot(x,y, 'ko')





for region in vor.regions:
    if not -1 in region:
        polygon = [vor.vertices[i] for i in region]
        plt.fill(*zip(*polygon))

# %%
x = float('inf')
a = 1/x
a
